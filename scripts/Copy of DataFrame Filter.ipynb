# %%
import numpy as np

import pandas as pd

import io

# %%
from google.colab import files
uploaded = files.upload()

# %%
df = pd.read_csv(io.StringIO(uploaded['First_200k.csv'].decode('utf-8')))

# %%
df

# %%
start= "2015-09-07 02:21:06.294925+00"
end= "2015-09-07 02:21:07.294983+00"
df = df[(df.timestamp >= start) & (df.timestamp <= end)]
	
df

# %%
df = df.sort_values(by=['timestamp'])
df
